# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
import os
import sys
import csv
from PyPDF2 import PdfFileReader

walk_dir = sys.argv[1]

print('walk_dir = ' + walk_dir)

# If your current working directory may change during script execution, it's recommended to
# immediately convert program arguments to an absolute path. Then the variable root below will
# be an absolute path as well. Example:
root = os.path.abspath(walk_dir)

print('walk_dir (absolute) = ' + os.path.abspath(walk_dir))
list_file_path = os.path.join(root, 'my-ebooks-list.csv')
with open(list_file_path, 'w', newline='') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(['File Name', 'File Path', 'No: of pages'])
    
    for (root, subdirs, files) in os.walk(walk_dir):
        print('--\nroot = ' + root)
        print('list_file_path = ' + list_file_path)
        
        with open(list_file_path, 'wb') as list_file:
            for subdir in subdirs:
                print ('\t- subdirectory ' + subdir)
                
            for filename in files:
                if not filename.endswith('.pdf'):
                    continue
                    
                file_details_list = []
                file_details_list.append(filename)
                file_path = os.path.join(root, filename)
                print('\t- file %s (full path: %s)' % (filename,
                        file_path))
                file_details_list.append(file_path)
                
                with open(file_path, 'rb') as pdf_file:
                    pdf_reader = PdfFileReader(pdf_file,strict=False)
                    print("The total number of pages in the pdf document is " + str(pdf_reader.numPages))
                    file_details_list.append(pdf_reader.numPages)
                writer.writerow(file_details_list)
# Out:
# walk_dir = /media/sf_Honey/StudyMaterials/C++
# walk_dir (absolute) = /media/sf_Honey/StudyMaterials/C++
# --
# root = /media/sf_Honey/StudyMaterials/C++
# list_file_path = /media/sf_Honey/StudyMaterials/C++/my-ebooks-list.csv
# 	- subdirectory Cheatsheets
# 	- subdirectory Conferences
# 	- subdirectory CPlusPlusTrainingSlides
# 	- subdirectory CPP11_Reference
# 	- subdirectory CPPNoteProfessionals
# 	- subdirectory FluentCPP_References
# 	- subdirectory PDF
# 	- subdirectory PluralsightTrainings
# 	- file 14-01-29_Stroustrup.pdf (full path: /media/sf_Honey/StudyMaterials/C++/14-01-29_Stroustrup.pdf)
# The total number of pages in the pdf document is 42
# 	- file Accelerated_C++,_Practical_Programming_by_Example_-_Andrew_Koenig,_Barbara_E._Moo_-_Addison Wesley_-_2000.pdf (full path: /media/sf_Honey/StudyMaterials/C++/Accelerated_C++,_Practical_Programming_by_Example_-_Andrew_Koenig,_Barbara_E._Moo_-_Addison Wesley_-_2000.pdf)
# The total number of pages in the pdf document is 387
# 	- file Addison Wesley - The C++ standard library_a tutorial and reference.pdf (full path: /media/sf_Honey/StudyMaterials/C++/Addison Wesley - The C++ standard library_a tutorial and reference.pdf)
# The total number of pages in the pdf document is 1190
# 	- file cplusplus.pdf (full path: /media/sf_Honey/StudyMaterials/C++/cplusplus.pdf)
# The total number of pages in the pdf document is 897
# 	- file CPlusPlusNotesForProfessionals.pdf (full path: /media/sf_Honey/StudyMaterials/C++/CPlusPlusNotesForProfessionals.pdf)
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected. [pdf.py:1736]
# The total number of pages in the pdf document is 708
# 	- file cpp-best-practices.pdf (full path: /media/sf_Honey/StudyMaterials/C++/cpp-best-practices.pdf)
# The total number of pages in the pdf document is 49
# 	- file cpp_primer_5th edition.pdf (full path: /media/sf_Honey/StudyMaterials/C++/cpp_primer_5th edition.pdf)
# The total number of pages in the pdf document is 1399
# 	- file CristinaVideiraLopes_ExercisesInStyle_C++_Slides.pdf (full path: /media/sf_Honey/StudyMaterials/C++/CristinaVideiraLopes_ExercisesInStyle_C++_Slides.pdf)
# The total number of pages in the pdf document is 62
# 	- file Effective Modern C pp By scott meyers.pdf (full path: /media/sf_Honey/StudyMaterials/C++/Effective Modern C pp By scott meyers.pdf)
# The total number of pages in the pdf document is 334
# 	- file Google C++ Style Guide.pdf (full path: /media/sf_Honey/StudyMaterials/C++/Google C++ Style Guide.pdf)
# The total number of pages in the pdf document is 71
# 	- file Head First Object-Oriented Analysis and Design.pdf (full path: /media/sf_Honey/StudyMaterials/C++/Head First Object-Oriented Analysis and Design.pdf)
# The total number of pages in the pdf document is 632
# 	- file HeadFirstDesignPatterns.pdf (full path: /media/sf_Honey/StudyMaterials/C++/HeadFirstDesignPatterns.pdf)
# The total number of pages in the pdf document is 619
# 	- file Modern C++ Design .pdf (full path: /media/sf_Honey/StudyMaterials/C++/Modern C++ Design .pdf)
# The total number of pages in the pdf document is 285
# 	- file modern-cpp-tutorial-en-us.pdf (full path: /media/sf_Honey/StudyMaterials/C++/modern-cpp-tutorial-en-us.pdf)
# The total number of pages in the pdf document is 89
# 	- file ModernCPPSyllabys.pdf (full path: /media/sf_Honey/StudyMaterials/C++/ModernCPPSyllabys.pdf)
# The total number of pages in the pdf document is 5
# 	- file OptimizingCpp.pdf (full path: /media/sf_Honey/StudyMaterials/C++/OptimizingCpp.pdf)
# The total number of pages in the pdf document is 99
# 	- file optimizing_cpp.pdf (full path: /media/sf_Honey/StudyMaterials/C++/optimizing_cpp.pdf)
# The total number of pages in the pdf document is 176
# 	- file Professional C++, 3rd Edition.pdf (full path: /media/sf_Honey/StudyMaterials/C++/Professional C++, 3rd Edition.pdf)
# The total number of pages in the pdf document is 987
# --
# root = /media/sf_Honey/StudyMaterials/C++/Cheatsheets
# list_file_path = /media/sf_Honey/StudyMaterials/C++/my-ebooks-list.csv
# 	- file C++-concurrency-cheatsheet.pdf (full path: /media/sf_Honey/StudyMaterials/C++/Cheatsheets/C++-concurrency-cheatsheet.pdf)
# The total number of pages in the pdf document is 1
# 	- file c++11-regex-cheatsheet.pdf (full path: /media/sf_Honey/StudyMaterials/C++/Cheatsheets/c++11-regex-cheatsheet.pdf)
# The total number of pages in the pdf document is 1
# 	- file c++11-stl-cheatsheet.pdf (full path: /media/sf_Honey/StudyMaterials/C++/Cheatsheets/c++11-stl-cheatsheet.pdf)
# The total number of pages in the pdf document is 1
# 	- file cpp17_language (2).pdf (full path: /media/sf_Honey/StudyMaterials/C++/Cheatsheets/cpp17_language (2).pdf)
# The total number of pages in the pdf document is 1
# 	- file cpp20_refcard_29th_jan (2).pdf (full path: /media/sf_Honey/StudyMaterials/C++/Cheatsheets/cpp20_refcard_29th_jan (2).pdf)
# The total number of pages in the pdf document is 1
# 	- file cpp_reference_sheet.pdf (full path: /media/sf_Honey/StudyMaterials/C++/Cheatsheets/cpp_reference_sheet.pdf)
# The total number of pages in the pdf document is 1
# 	- file STL Quick Reference 1.29.pdf (full path: /media/sf_Honey/StudyMaterials/C++/Cheatsheets/STL Quick Reference 1.29.pdf)
# The total number of pages in the pdf document is 8
# --
# root = /media/sf_Honey/StudyMaterials/C++/Conferences
# list_file_path = /media/sf_Honey/StudyMaterials/C++/my-ebooks-list.csv
# 	- subdirectory MeetingCPP
# --
# root = /media/sf_Honey/StudyMaterials/C++/Conferences/MeetingCPP
# list_file_path = /media/sf_Honey/StudyMaterials/C++/my-ebooks-list.csv
# 	- file Meeting C++ 2020 Static Initialization Order Fiasco.pdf (full path: /media/sf_Honey/StudyMaterials/C++/Conferences/MeetingCPP/Meeting C++ 2020 Static Initialization Order Fiasco.pdf)
# The total number of pages in the pdf document is 153
# 	- file Templates_Debugging_Benchmarking_Jonathan.pdf (full path: /media/sf_Honey/StudyMaterials/C++/Conferences/MeetingCPP/Templates_Debugging_Benchmarking_Jonathan.pdf)
# The total number of pages in the pdf document is 86
# --
# root = /media/sf_Honey/StudyMaterials/C++/CPlusPlusTrainingSlides
# list_file_path = /media/sf_Honey/StudyMaterials/C++/my-ebooks-list.csv
# 	- file lecture_slides_for_programming_in_c++-2020-02-29.pdf (full path: /media/sf_Honey/StudyMaterials/C++/CPlusPlusTrainingSlides/lecture_slides_for_programming_in_c++-2020-02-29.pdf)
# The total number of pages in the pdf document is 2565
# --
# root = /media/sf_Honey/StudyMaterials/C++/CPP11_Reference
# list_file_path = /media/sf_Honey/StudyMaterials/C++/my-ebooks-list.csv
# 	- subdirectory CPP11_Capsule_PPT
# 	- file 14-01-29_Stroustrup.pdf (full path: /media/sf_Honey/StudyMaterials/C++/CPP11_Reference/14-01-29_Stroustrup.pdf)
# The total number of pages in the pdf document is 42
# 	- file c++11_AnOverview.pdf (full path: /media/sf_Honey/StudyMaterials/C++/CPP11_Reference/c++11_AnOverview.pdf)
# The total number of pages in the pdf document is 57
# 	- file C++11_smart_ptrs.pdf (full path: /media/sf_Honey/StudyMaterials/C++/CPP11_Reference/C++11_smart_ptrs.pdf)
# The total number of pages in the pdf document is 14
# 	- file cpp11NotesSample.pdf (full path: /media/sf_Honey/StudyMaterials/C++/CPP11_Reference/cpp11NotesSample.pdf)
# The total number of pages in the pdf document is 43
# 	- file Learn from Folly source code the new C++11 features.pdf (full path: /media/sf_Honey/StudyMaterials/C++/CPP11_Reference/Learn from Folly source code the new C++11 features.pdf)
# The total number of pages in the pdf document is 7
# 	- file Software Development Tools_ How C++11_14 can im...pdf (full path: /media/sf_Honey/StudyMaterials/C++/CPP11_Reference/Software Development Tools_ How C++11_14 can im...pdf)
# The total number of pages in the pdf document is 4
# --
# root = /media/sf_Honey/StudyMaterials/C++/CPP11_Reference/CPP11_Capsule_PPT
# list_file_path = /media/sf_Honey/StudyMaterials/C++/my-ebooks-list.csv
# 	- file C++11.pdf (full path: /media/sf_Honey/StudyMaterials/C++/CPP11_Reference/CPP11_Capsule_PPT/C++11.pdf)
# The total number of pages in the pdf document is 72
# --
# root = /media/sf_Honey/StudyMaterials/C++/CPPNoteProfessionals
# list_file_path = /media/sf_Honey/StudyMaterials/C++/my-ebooks-list.csv
# 	- file CPlusPlusNotesForProfessionals.pdf (full path: /media/sf_Honey/StudyMaterials/C++/CPPNoteProfessionals/CPlusPlusNotesForProfessionals.pdf)
# The total number of pages in the pdf document is 708
# --
# root = /media/sf_Honey/StudyMaterials/C++/FluentCPP_References
# list_file_path = /media/sf_Honey/StudyMaterials/C++/my-ebooks-list.csv
# --
# root = /media/sf_Honey/StudyMaterials/C++/PDF
# list_file_path = /media/sf_Honey/StudyMaterials/C++/my-ebooks-list.csv
# 	- file 1_Introduction.pdf (full path: /media/sf_Honey/StudyMaterials/C++/PDF/1_Introduction.pdf)
# The total number of pages in the pdf document is 18
# 	- file 2_Basic_OO_Design_Principles.pdf (full path: /media/sf_Honey/StudyMaterials/C++/PDF/2_Basic_OO_Design_Principles.pdf)
# The total number of pages in the pdf document is 56
# 	- file 3_Concepts_and_the_STL.pdf (full path: /media/sf_Honey/StudyMaterials/C++/PDF/3_Concepts_and_the_STL.pdf)
# The total number of pages in the pdf document is 111
# 	- file 4_Class_Design.pdf (full path: /media/sf_Honey/StudyMaterials/C++/PDF/4_Class_Design.pdf)
# The total number of pages in the pdf document is 200
# 	- file 5_Exception_Safety.pdf (full path: /media/sf_Honey/StudyMaterials/C++/PDF/5_Exception_Safety.pdf)
# The total number of pages in the pdf document is 44
# 	- file 6_Dynamic_Polymorphism.pdf (full path: /media/sf_Honey/StudyMaterials/C++/PDF/6_Dynamic_Polymorphism.pdf)
# The total number of pages in the pdf document is 56
# 	- file 7_Non-Intrusive_Design.pdf (full path: /media/sf_Honey/StudyMaterials/C++/PDF/7_Non-Intrusive_Design.pdf)
# The total number of pages in the pdf document is 14
# 	- file 8_Summary.pdf (full path: /media/sf_Honey/StudyMaterials/C++/PDF/8_Summary.pdf)
# The total number of pages in the pdf document is 5
# 	- file Literature.pdf (full path: /media/sf_Honey/StudyMaterials/C++/PDF/Literature.pdf)
# The total number of pages in the pdf document is 25
# --
# root = /media/sf_Honey/StudyMaterials/C++/PluralsightTrainings
# list_file_path = /media/sf_Honey/StudyMaterials/C++/my-ebooks-list.csv
